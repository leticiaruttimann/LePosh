# %% [markdown]
# Aluna: Letícia Rüttimann
# RG: 49.351.201-2

# %%
import pymongo
from bson.objectid import ObjectId
from pprint import pprint
from pymongo import MongoClient
client = MongoClient('localhost', 27017)
db = client['Mkplc']
print(db)

# %% [markdown]
# # Criação category collection and documents

# %%
categorias = [
{
  "_id": "cat01",
  "name": "Feminino",
  "ancestors": "[]",
  "parent": "null"
},{
  "_id": "cat02",
  "name": "Masculino",
  "ancestors": "[]",
  "parent": "null"
},{
  "_id": "cat03",
  "name": "Novidades",
  "ancestors": "[]",
  "parent": "null"
},{
  "_id": "cat04",
  "name": "Designers",
  "ancestors": "[]",
  "parent": "null"
},{
  "_id": "sub01cat04",
  "name": "Gucci",
  "ancestors": "Designers",
  "parent": "Designers"
},{
  "_id": "sub02cat04",
  "name": "Givenchy",
  "ancestors": "Designers",
  "parent": "Designers"
},{
  "_id": "sub03cat04",
  "name": "Balenciaga",
  "ancestors": "Designers",
  "parent": "Designers"
},{
  "_id": "sub04cat04",
  "name": "Balmain",
  "ancestors": "Designers",
  "parent": "Designers"
},{
  "_id": "sub01cat03",
  "name": "Masculino",
  "ancestors": "Novidades",
  "parent": "Novidades"
},{
  "_id": "sub02cat03",
  "name": "Feminino",
  "ancestors": "Novidades",
  "parent": "Novidades"
},{
  "_id": "sub03cat03",
  "name": "Designers",
  "ancestors": "Novidades",
  "parent": "Novidades"
},{
  "_id": "sub01cat02",
  "name": "Bolsas",
  "ancestors": "Masculino",
  "parent": "Masculino"
},{
  "_id": "sub02cat02",
  "name": "Sapatos",
  "ancestors": "Masculino",
  "parent": "Masculino"
},{
  "_id": "sub03cat02",
  "name": "Relógios",
  "ancestors": "Masculino",
  "parent": "Masculino"
},{
  "_id": "sub04cat02",
  "name": "Roupas",
  "ancestors": "Masculino",
  "parent": "Masculino"
},{
  "_id": "sub05cat02", 
  "name": "Joias",
  "ancestors": "Masculino",
  "parent": "Masculino"
},{
  "_id": "sub01sub04cat02",  
  "name": "Camisa",
  "ancestors": [
    "Masculino",
    "Roupas"
  ],
  "parent": "Roupas"
},{
  "_id": "sub02sub04cat02",   
  "name": "Jaqueta",
  "ancestors": [
    "Masculino",
    "Roupas"
  ],
  "parent": "Roupas"
},{
  "_id": "sub03sub04cat02",  
  "name": "Bermuda",
  "ancestors": [
    "Masculino",
    "Roupas"
  ],
  "parent": "Roupas"
},{
  "_id": "sub04sub04cat02",  
  "name": "Calça",
  "ancestors": [
    "Masculino",
    "Roupas"
  ],
  "parent": "Roupas"
}]

result = db.category.insert_many(categorias)

# %% [markdown]
# # Criação seller collection e documents

# %%
lojas = [{
  "_id": "LJ001",
  "name": "Loja Ruttimann",
  "rating": 5,
  "classification": "Expert",
  "total_sales": 80,
  "contact_info": {
    "country": "Estados Unidos",
    "email": "ruttimann@gmail.com"
  },
  "joined": "2019-01-01"
},{
  "_id": "LJ006",
  "name": "Swiss Luxury Items",
  "rating": 4.3,
  "classification": "Premium",
  "total_sales": 1,
  "contact_info": {
    "country": "Brasil",
    "email": "swissitems@gmail.com"
  },
  "joined": "2021-01-01"
},{
  "_id": "LJ003",
  "name": "Loja Só Luxo",
  "rating": 4.7,
  "classification": "Premium",
  "total_sales": 4,
  "contact_info": {
    "country": "Suíça",
    "email": "soluxo@gmail.com"
  },
  "joined": "2021-07-14"
},{
  "_id": "LJ002",
  "name": "Loja Moretti",
  "rating": 4,
  "classification": "null",
  "total_sales": 0,
  "contact_info": {
    "country": "Brasil",
    "email": "soluxo@gmail.com"
  },
  "joined": "2021-08-01"
},{
  "_id": "LJ005",
  "name": "Canada Imports",
  "rating": 4.9,
  "classification": "Profissional",
  "total_sales": 560,
  "contact_info": {
    "country": "Canada",
    "email": "canimports@gmail.com"
  },
  "joined": "2017-08-14"
},{
  "_id": "LJ004",
  "name": "Brazil Imports",
  "rating": 4.3,
  "classification": "Profissional",
  "total_sales": 860,
  "contact_info": {
    "country": "Brasil",
    "email": "braim@gmail.com"
  },
  "joined": "2015-03-29"
},{
  "_id": "LJ007",
  "name": "Zhuzhu imports",
  "rating": 0,
  "classification": "null",
  "total_sales": 0,
  "contact_info": {
    "country": "Estados Unidos",
    "email": "zhuzhu@gmail.com"
  },
  "joined": "2020-02-05"
},{
  "_id": "LJ008",
  "name": "Danee",
  "rating": 0,
  "classification": "null",
  "total_sales": 0,
  "contact_info": {
    "country": "Dinamarca",
    "email": "danee@gmail.com"
  },
  "joined": "2021-01-30"
},{
  "_id": "LJ009",
  "name": "Toni S.",
  "rating": 0,
  "classification": "null",
  "total_sales": 0,
  "contact_info": {
    "country": "Canada",
    "email": "toniida@gmail.com"
  },
  "joined": "2020-09-10"
},{
  "_id": "LJ010",
  "name": "Gemma M.",
  "rating": 0,
  "classification": "null",
  "total_sales": 0,
  "contact_info": {
    "country": "Italia",
    "email": "gemma@gmail.com"
  },
  "joined": "2020-12-15"
},{
  "_id": "LJ011",
  "name": "Laura Mateuti",
  "rating": 0,
  "classification": "null",
  "total_sales": 0,
  "contact_info": {
    "country": "Italia",
    "email": "lmateuti@gmail.com"
  },
  "joined": "2021-03-15"
}]

result = db.seller.insert_many(lojas)

# %% [markdown]
# # Criação product collection e documents

# %%
produtos = [{
  "_id": "PRDRL0001",
  "name": "Relógio Pasha - Cartier",
  "cat": {
    "_id": "sub03cat02",
    "name": "Relógios"
  },
  "seller_id": "LJ001",
  "condition": {
    "description": "Muito bom",
    "is_used": True,
    "has_tags": "Sem etiqueta"
  },
  "details": {
    "Bracelet_material": "Crocodilo",
    "designer": "Cartier",
    "model": "Pasha",
    "mechanism": "Automático",
    "measurements": {
      "Face_diameter": 4.2
    },
    "colors": "Preto",
    "images": [
      "images/pasha001lj001b0ee.jpg",
      "images/pasha002lj001b0ee.jpg"
    ]
  },
  "sku": "1407ABC"
},{
  "_id": "PRDRL0002",
  "name": "Relógio Gucci",
  "cat": {
    "_id": "sub03cat02",
    "name": "Relógios"
  },
  "seller_id": "LJ001",
  "condition": [
    {
      "description": "Novo",
      "is_used": False,
      "has_tags": "Com etiqueta"
    }
  ],
  "details": [
    {
      "Bracelet_material": "Couro",
      "designer": "Gucci",
      "mechanism": "Quartz",
      "measurements": {
        "Face_diameter": 4.3
      },
      "colors": [
        "Branco",
        "Verde",
        "Vermelho"
      ],
      "images": [
        "images/watchgucci001lj001b0ee.jpg",
        "images/watchgucci002lj001b0ee.jpg"
      ]
    }
  ],
  "sku": "1418ABC"
},{
  "_id": "PRDRL0003",
  "name": "Relógio Sky-Dweller Rolex ",
  "cat": {
    "_id": "sub03cat02",
    "name": "Relógios"
  },
  "seller_id": "LJ001",
  "condition": {
    "description": "Excelente",
    "is_used": "Usado",
    "has_tags": "Sem etiqueta"
  },
  "details": {
    "Bracelet_material": "Outro",
    "designer": "Rolex",
    "model": "Sky-Dweller",
    "mechanism": "Automático",
    "measurements": {
      "Face_diameter": 106.7
    },
    "colors": "Preto",
    "images": [
      "images/sky001lj001b0ee.jpg",
      "images/sky002lj001b0ee.jpg"
    ]
  },
  "sku": "1908ABC"
},{
  "_id":"PRDTS0001",
  "name": "T-shirt preta Givenchy",
  "cat": {
    "_id": "sub03cat02",
    "name": "Camisa"
  },
  "seller_id": "LJ006",
  "condition": {
    "description": "Novo",
    "is_used": "Nunca usado",
    "has_tags": "Com etiqueta"
  },
  "details": {
    "size": "P",
    "designer": "Givenchy",
    "model": "t-shirt",
    "Material": "Algodão",
    "colors": "Preto",
    "images": [
      "images/teegivenchy001lj0062456.jpg",
      "images/teegivenchy002lj0062456.jpg"
    ]
  },
  "sku": "5696ABC"
},{
  "_id":"PRDTS0002",
  "name": "T-shirt navy Fendi",
  "cat": {
    "_id": "sub01sub04cat02",
    "name": "Camisa"
  },
  "seller_id": "LJ006",
  "condition": {
    "description": "Novo",
    "is_used": False,
    "has_tags": "Com etiqueta"
  },
  "details": {
    "size": "L",
    "designer": "Fendi",
    "model": "T-shirt",
    "Material": "Algodão",
    "colors": "Azul escuro",
    "images": [
      "images/teefendi001lj0062456.jpg",
      "images/teefendi002lj0062456.jpg"
    ]
  },
  "sku": "5423ABC"
},{
  "_id": "PRDTS0003",
  "name": "T-shirt linho Balmain",
  "cat": [
    {
      "_id": "sub01sub04cat02",
      "name": "Camisa"
    },
    {
      "_id": "sub04cat04",
      "name": "Balmain"
    }
  ],
  "seller_id": "LJ001",
  "condition": {
    "description": "Bom",
    "is_used": True,
    "has_tags": "Sem etiqueta"
  },
  "details": {
    "size": "M",
    "designer": "Balmain",
    "model": "T-shirt",
    "Material": "Linho",
    "colors": "Azul",
    "images": [
      "images/teeBalmain001lj0012456.jpg",
      "images/teeBalmain002lj0012456.jpg"
    ]
  },
  "sku": "8756GHI"
},{
  "_id": "PRDDS0001",
  "name": "Vestido floral Givenchy rosa",
  "cat": [
    {
      "_id": "sub02cat04",
      "name": "Givenchy"
    },
    {
      "_id": "sub02cat03",
      "name": "Feminino"
    }
  ],
  "seller_id": "LJ003",
  "condition": {
    "description": "Excelente",
    "is_used": True,
    "has_tags": "Sem etiqueta"
  },
  "details": {
    "size": "G",
    "designer": "Givenchy",
    "model": "T-shirt",
    "Material": "Linho",
    "colors": "Rosa",
    "images": [
      "images/dressGivenchy001lj0032456.jpg",
      "images/dressGivenchy002lj0032456.jpg"
    ]
  },
  "sku": "3654ZZI"
},{
  "_id": "PRDDS0002",
  "name": "Vestido de couro Gucci preto",
  "cat": [
    {
      "_id": "sub01cat04",
      "name": "Gucci"
    },
    {
      "_id": "sub02cat03",
      "name": "Feminino"
    }
  ],
  "seller_id": "LJ001",
  "condition": {
    "description": "Excelente",
    "is_used": True,
    "has_tags": "Sem etiqueta"
  },
  "details": {
    "size": "M",
    "designer": "Gucci",
    "model": "Mid",
    "Material": "Couro",
    "colors": "Preto",
    "images": [
      "images/dressGucci001lj0012456.jpg",
      "images/dressGucci001lj0012456.jpg"
    ]
  },
  "sku": "3210ABC"
},{
  "_id": "PRDSK0001",
  "name": "Saia mid off-white Balmain",
  "cat": [
    {
      "_id": "sub04cat04",
      "name": "Balmain"
    },
    {
      "_id": "sub02cat03",
      "name": "Feminino"
    }
  ],
  "seller_id": "LJ003",
  "condition": {
    "description": "Muito bom",
    "is_used": True,
    "has_tags": "Sem etiqueta"
  },
  "details": {
    "size": "M",
    "designer": "Balmain",
    "model": "Lápis",
    "Material": "Seda",
    "colors": "off-white",
    "images": [
      "images/skirtBalmain001lj0032456.jpg",
      "images/skirtBalmain001lj0032456.jpg"
    ]
  },
  "sku": "4569ABC"
},{
  "_id":"PRDSH0001",
  "name": "Bermuda azul Gucci",
  "cat": [
    {
      "_id": "sub01cat04",
      "name": "Gucci"
    },
    {
      "_id": "sub03sub04cat02",
      "name": "Bermuda"
    }
  ],
  "seller_id": "LJ002",
  "condition": {
    "description": "Novo",
    "is_used": False,
    "has_tags": "Com etiqueta"
  },
  "details": {
    "size": "M",
    "designer": "Gucci",
    "model": "Mid",
    "Material": "Algodão",
    "colors": [
      "Azul",
      "Branco"
    ],
    "images": [
      "images/shorts001lj0022456.jpg",
      "images/shorts001lj0022456.jpg"
    ]
  },
  "sku": "3210ABC"
},{
  "_id": "PRDSH0002",
  "name": "Bermuda Jeans Givenchy",
  "cat": [
    {
      "_id": "sub02cat04",
      "name": "Givenchy"
    },
    {
      "_id": "sub03sub04cat02",
      "name": "Bermuda"
    }
  ],
  "seller_id": "LJ001",
  "condition": {
    "description": "Novo",
    "is_used": False,
    "has_tags": "Com etiqueta"
  },
  "details": {
    "size": "M",
    "designer": "Gucci",
    "model": "Mid",
    "Material": "Jeans",
    "colors": [
      "Azul",
      "Branco"
    ],
    "images": [
      "images/shortsGivenchy001lj0022456.jpg",
      "images/shortsGivenchy001lj0022456.jpg"
    ]
  },
  "sku": "4400EFG"
},{
  "_id":"PRDJT0001",
  "name": "Jaqueta Couro Balmain",
  "cat": [
    {
      "_id": "sub04cat04",
      "name": "Balmain"
    },
    {
      "_id": "sub02sub04cat02",
      "name": "Jaqueta"
    }
  ],
  "seller_id": "LJ006",
  "condition": {
    "description": "Novo",
    "is_used": False,
    "has_tags": "Com etiqueta"
  },
  "details": {
    "size": "P",
    "designer": "Balmain",
    "model": "Justo",
    "Material": "Couro",
    "colors": [
      "Preto",
      "Vermelho"
    ],
    "images": [
      "images/jacketBalmain001lj0062456.jpg",
      "images/jacketBalmain001lj0062456.jpg"
    ]
  },
  "sku": "4400EFG"
},{
  "_id":"PRDJT0002",
  "name": "Jaqueta Jeans Balmain Vintage",
  "cat": [
    {
      "_id": "sub04cat04",
      "name": "Balmain"
    },
    {
      "_id": "sub02sub04cat02",
      "name": "Jaqueta"
    }
  ],
  "seller_id": "LJ006",
  "condition": {
    "description": "Bom",
    "is_used": False,
    "has_tags": "Sem etiqueta"
  },
  "details": {
    "size": "G",
    "designer": "Balmain",
    "model": "Justo",
    "Material": "Couro",
    "colors": "Branco",
    "images": [
      "images/jacketBalmainv006lj0062456.jpg",
      "images/jacketBalmainv006lj0062456.jpg"
    ]
  },
  "sku": "6633KLM"
},{
  "_id": "PRDJT0003",
  "name": "Jaqueta Inverno Balmain",
  "cat": [
    {
      "_id": "sub04cat04",
      "name": "Balmain"
    },
    {
      "_id": "sub02sub04cat02",
      "name": "Jaqueta"
    }
  ],
  "seller_id": "LJ005",
  "condition": {
    "description": "Novo",
    "is_used": False,
    "has_tags": "Com etiqueta"
  },
  "details": {
    "size": "P",
    "designer": "Balmain",
    "model": "Com zíper",
    "Material": "Algodão",
    "colors": [
      "Preto",
      "Azul"
    ],
    "images": [
      "images/jacketBalmain001lj002456.jpg",
      "images/jacketBalmain001lj002456.jpg"
    ]
  },
  "sku": "9999LLL"
},{
  "_id": "PRDPT0001",
  "name": "Calça couro Givenchy ",
  "cat": [
    {
      "_id": "sub02cat04",
      "name": "Givenchy"
    },
    {
      "_id": "sub04sub04cat02",
      "name": "Calça"
    }
  ],
  "seller_id": "LJ006",
  "condition": {
    "description": "Ótimo",
    "is_used": True,
    "has_tags": "Sem etiqueta"
  },
  "details": {
    "size": "M",
    "designer": "Givenchy",
    "Material": "Couro",
    "colors": "White",
    "images": [
      "images/pantsGivenchy001lj0062456.jpg",
      "images/pantsGivenchy001lj0062456.jpg"
    ]
  },
  "sku": "4567XXL"
},{
  "_id": "PRDDS0007",
  "name": "Vestido mid verão Gucci off-white",
  "cat": [
    {
      "_id": "sub01cat04",
      "name": "Gucci"
    },
    {
      "_id": "sub02cat03",
      "name": "Feminino"
    }
  ],
  "seller_id": "LJ004",
  "condition": {
    "description": "Ótimo",
    "is_used": True,
    "has_tags": "Sem etiqueta"
  },
  "details": {
    "size": "M",
    "designer": "Gucci",
    "Material": "Algodão",
    "colors": "Off-white",
    "images": [
      "images/dressGucci001lj0042456.jpg",
      "images/dresGucci002lj0042456.jpg"
    ]
  },
  "sku": "1236IJK"
},{
  "_id": "PRDDS0003",
  "name": "Vestido silk mid Diane Von Furstenberg",
  "cat": {
    "_id": "sub02cat03",
    "name": "Feminino"
  },
  "seller_id": "LJ004",
  "condition": {
    "description": "Ótimo",
    "is_used": True,
    "has_tags": "Sem etiqueta"
  },
  "details": {
    "size": "P",
    "designer": "Diane Von Furstenberg",
    "model": "Longo",
    "Material": "Seda",
    "colors": "Azul",
    "images": [
      "images/dressDNF001lj0042456.jpg",
      "images/dresDNF002lj0042456.jpg"
    ]
  },
  "sku": "6666JKL"
},{
  "_id": "PRDDS0004",
  "name": "Vestido Branco Alexander Wang",
  "cat": {
    "_id": "sub02cat03",
    "name": "Feminino"
  },
  "seller_id": "LJ004",
  "condition": {
    "description": "Excelente",
    "is_used": True,
    "has_tags": "Sem etiqueta"
  },
  "details": {
    "size": "P",
    "designer": "Alexander Wang",
    "model": "Justo",
    "Material": "Algodão",
    "colors": "Brango",
    "images": [
      "images/dressWang001lj0042456.jpg",
      "images/dressWang002lj0042456.jpg"
    ]
  },
  "sku": "6545ABC"
},{
  "_id": "PRDDS0005",
  "name": "Vestido Silk mini Alexander McQueen",
  "cat": {
    "_id": "sub02cat03",
    "name": "Feminino"
  },
  "seller_id": "LJ005",
  "condition": {
    "description": "Novo",
    "is_used": False,
    "has_tags": "Com etiqueta"
  },
  "details": {
    "size": "M",
    "designer": "Alexander McQueen",
    "model": "Justo",
    "Material": "Seda",
    "colors": "Vermelho",
    "images": [
      "images/dressMcQueen001lj0052456.jpg",
      "images/dressMcQueen002lj0052456.jpg"
    ]
  },
  "sku": "7458OPQ"
},{
  "_id":  "PRDDS0006",
  "name": "Vestido mid preto Moschino",
  "cat": {
    "_id": "sub02cat03",
    "name": "Feminino"
  },
  "seller_id": "LJ003",
  "condition": {
    "description": "Muito bom",
    "is_used": True,
    "has_tags": "Sem etiqueta"
  },
  "details": {
    "size": "P",
    "designer": "Moschino",
    "model": "Mid",
    "Material": "Couro",
    "colors": "Preto",
    "images": [
      "images/dressMoschino001lj0032456.jpg",
      "images/dressMoschino001lj0032456.jpg"
    ]
  },
  "sku": "7855EFG"
},{
  "_id":"PRDRL0004",
  "name": "Relógio Gucci",
  "cat": {
    "_id": "sub03cat02",
    "name": "Relógios"
  },
  "seller_id": "LJ001",
  "condition": {
    "description": "Novo",
    "is_used": False,
    "has_tags": "Com etiqueta"
  },
  "details": {
    "Bracelet_material": "Aço",
    "designer": "Gucci",
    "mechanism": "Quartz",
    "measurements": {
      "Face_diameter": 3.6
    },
    "colors": "Prata",
    "images": [
      "images/watchguccisilver001lj001b0ee.jpg",
      "images/watchguccisilver002lj001b0ee.jpg"
    ]
  },
  "sku": "1237ABC"
}]

result = db.product.insert_many(produtos)

# %% [markdown]
# # Consultas

# %% [markdown]
# 1) Vendedores sem anúncio de produto(s) na plataforma

# %%
result = db.seller.aggregate([
  {
    "$lookup": {
      "from": "product",
      "localField": "_id",
      "foreignField": "seller_id",
      "as": "productSeller"
    }
  },
    {
    "$match": {
      "productSeller": []
    }
  },
  {
    "$project": {
      "productSeller": {
        "_id":1
      }
    }
  }
])

pprint(list(result))
# Out:
# [{'_id': 'LJ007', 'productSeller': []},
#  {'_id': 'LJ008', 'productSeller': []},
#  {'_id': 'LJ009', 'productSeller': []},
#  {'_id': 'LJ010', 'productSeller': []},
#  {'_id': 'LJ011', 'productSeller': []}]

# %% [markdown]
# 2) Ranking de vendedores com mais produtos listados na plataforma

# %%
pipeline = [
            {
                "$group": {
                    "_id": "$seller_id", "Qtd": {
                        "$sum": 1
                    }
                }
            },
            {
                "$match": 
                {"Qtd":{
                    "$gt":0
                }
                }
            },
            {
                "$sort":  {
                    "Qtd": -1
                }
            }, 
            
]

result = db.product.aggregate(pipeline)
pprint(list(result))
# Out:
# [{'Qtd': 7, '_id': 'LJ001'},
#  {'Qtd': 5, '_id': 'LJ006'},
#  {'Qtd': 3, '_id': 'LJ004'},
#  {'Qtd': 3, '_id': 'LJ003'},
#  {'Qtd': 2, '_id': 'LJ005'},
#  {'Qtd': 1, '_id': 'LJ002'}]

# %% [markdown]
# 3) Subcategoria sem produto listado

# %%
pipeline = db.category.aggregate(
[
    {
        "$lookup": {
            "from": "product", 
            "localField": "name",  
            "foreignField": "cat.name",
            "as": "references"
        }
    },
    {
        "$match": {
            "references": [], 
        }   
        },
    {
    "$project": {
     "name": 1,
        "_id":0,
        "ancestors":1
    }
  }
]);

list (pipeline)
# Out:
# [{'name': 'Masculino', 'ancestors': '[]'},
#  {'name': 'Novidades', 'ancestors': '[]'},
#  {'name': 'Designers', 'ancestors': '[]'},
#  {'name': 'Balenciaga', 'ancestors': 'Designers'},
#  {'name': 'Masculino', 'ancestors': 'Novidades'},
#  {'name': 'Designers', 'ancestors': 'Novidades'},
#  {'name': 'Bolsas', 'ancestors': 'Masculino'},
#  {'name': 'Sapatos', 'ancestors': 'Masculino'},
#  {'name': 'Roupas', 'ancestors': 'Masculino'},
#  {'name': 'Joias', 'ancestors': 'Masculino'}]

# %% [markdown]
# 4) Designers mais anunciados pelos lojistas com a condição usado (não é um produto novo)

# %%
pipeline = db.product.aggregate([
     {"$match": {
        "condition.is_used": True
    }
     },
    { "$group": { "_id": "$details.designer", "qtd": { "$sum": 1 }} },
    { "$sort": { "qtd": -1 } }
  ])
pprint(list(pipeline))
# Out:
# [{'_id': 'Givenchy', 'qtd': 2},
#  {'_id': 'Gucci', 'qtd': 2},
#  {'_id': 'Balmain', 'qtd': 2},
#  {'_id': 'Alexander Wang', 'qtd': 1},
#  {'_id': 'Diane Von Furstenberg', 'qtd': 1},
#  {'_id': 'Moschino', 'qtd': 1},
#  {'_id': 'Cartier', 'qtd': 1}]

# %% [markdown]
# 5) Vendedores com produtos listados para venda e rating maior que 4.5

# %%
result = db.seller.aggregate([
  {
    "$lookup": {
      "from": "product",
      "localField": "_id",
      "foreignField": "seller_id",
      "as": "productSeller"
    }
  },

    {
    "$match": {
       "rating": { 
                "$gt":4.5}
    }},
  {
    "$project": {
      "productSeller": {
        "name":1
      }
    }
  }
    
])

pprint(list(result))
# Out:
# [{'_id': 'LJ001',
#   'productSeller': [{'name': 'Relógio Pasha - Cartier'},
#                     {'name': 'Relógio Gucci'},
#                     {'name': 'Relógio Sky-Dweller Rolex '},
#                     {'name': 'T-shirt linho Balmain'},
#                     {'name': 'Vestido de couro Gucci preto'},
#                     {'name': 'Bermuda Jeans Givenchy'},
#                     {'name': 'Relógio Gucci'}]},
#  {'_id': 'LJ003',
#   'productSeller': [{'name': 'Vestido floral Givenchy rosa'},
#                     {'name': 'Saia mid off-white Balmain'},
#                     {'name': 'Vestido mid preto Moschino'}]},
#  {'_id': 'LJ005',
#   'productSeller': [{'name': 'Jaqueta Inverno Balmain'},
#                     {'name': 'Vestido Silk mini Alexander McQueen'}]}]

# %% [markdown]
# # Consultas Extras

# %% [markdown]
# Quantos documentos tem na collection product

# %%
result = db.product.aggregate( [
  {
    "$group": {
       "_id": "null",
       "count": { "$count": { } }
    }
  }
] )

pprint(list(result))
# Out:
# [{'_id': 'null', 'count': 21}]

# %% [markdown]
# Total produtos da categoria Relógio

# %%
products = db.product.aggregate(
  [
    {
      "$match": {
       "cat.name": "Relógios"
      }
    },
    {
      "$count": "Qtd_produtos"
    }
  ]
)

pprint(list(products))
# Out:
# [{'Qtd_produtos': 4}]

# %% [markdown]
# Nome de todos os produtos que estão listados na categoria "camisa" (insensitive case)

# %%
result = db.product.find({'cat.name':{'$regex':'^camisa', '$options': 'i'}},
                        {'name':1,'_id':0}
                       )
list(result)
# Out:
# [{'name': 'T-shirt preta Givenchy'},
#  {'name': 'T-shirt navy Fendi'},
#  {'name': 'T-shirt linho Balmain'}]

# %% [markdown]
# Todas subcategorias do vendedor LJ003

# %%
pipeline = db.product.aggregate([
    {"$match": {
        "seller_id": "LJ003"
    } 
    },
    { "$group": { "_id": "$cat.name", "qtd": { "$sum": 1 }} },
    { "$sort": { "count": -1 } }
  ])
pprint(list(pipeline))
# Out:
# [{'_id': 'Feminino', 'qtd': 1},
#  {'_id': ['Balmain', 'Feminino'], 'qtd': 1},
#  {'_id': ['Givenchy', 'Feminino'], 'qtd': 1}]

# %% [markdown]
# Quantas categorias se repetem e quantos produtos existem em cada uma delas (descending order)

# %%
pipeline = [
            {"$group": {"_id": "$cat.name", "count": {"$sum": 1}}},
            {"$match": {"count":{"$gt":1}}},
            {"$sort":  {"count": -1}},
            
]

result = db.product.aggregate(pipeline)
pprint(list(result))
# Out:
# [{'_id': 'Feminino', 'count': 4},
#  {'_id': 'Relógios', 'count': 4},
#  {'_id': ['Balmain', 'Jaqueta'], 'count': 3},
#  {'_id': ['Gucci', 'Feminino'], 'count': 2},
#  {'_id': 'Camisa', 'count': 2}]

# %% [markdown]
# Todos produtos da categoria Jaqueta

# %%
result = db.product.find( { "cat.name": { "$all": [ "Jaqueta"] } } ,{"name":1} )

pprint(list(result))
# Out:
# [{'_id': 'PRDJT0001', 'name': 'Jaqueta Couro Balmain'},
#  {'_id': 'PRDJT0002', 'name': 'Jaqueta Jeans Balmain Vintage'},
#  {'_id': 'PRDJT0003', 'name': 'Jaqueta Inverno Balmain'}]
